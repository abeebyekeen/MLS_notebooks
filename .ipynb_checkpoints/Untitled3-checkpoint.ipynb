# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as st
# %matplotlib inline

order_p2 = []
with open("RgData.dat") as alldata:
    alldata_lines = alldata.readlines()
    for line in alldata_lines:
        data_point = str(line).split("\n")
        order_p2.append(float(data_point[0]))

# %%
plt.hist(order_p2, density=True, bins=105, label="Rg", color='#F8C471', alpha=0.6)
a=plt.hist(order_p2, density=True, bins=105)
ys = a[0]; xs = a[1]
plt.xlabel('RMSD (Å)')
plt.ylabel('Count')
kde_xs = np.linspace(min(order_p2), max(order_p2), 300)
kde = st.gaussian_kde(order_p2, bw_method='silverman')
kde_ys=kde.pdf(kde_xs)
plt.plot(kde_xs, kde.pdf(kde_xs), label="Rg.PDF")
plt.legend()
plt.ylabel("Density")
plt.xlabel("Data")
plt.title("Histogram");

# %%
plt.hist(order_p2, density=True, bins=105, label="Rg", color='#F8C471', alpha=0.6)
a=plt.hist(order_p2, density=True, bins=105)
ys = a[0]; xs = a[1]
plt.xlabel('RMSD (Å)')
plt.ylabel('Count')
kde_xs = np.linspace(min(order_p2), max(order_p2), 300)
ttt=str('scott')
# bandw=str("'"+ttt+"'")
# bandw='scott'
bandw_1=ttt
bandw=bandw_1
print(bandw_1)
print(bandw)
kde = st.gaussian_kde(order_p2, bw_method=str('scott'))
kde_ys=kde.pdf(kde_xs)
plt.plot(kde_xs, kde.pdf(kde_xs), label="Rg.PDF")
plt.legend()
plt.ylabel("Density")
plt.xlabel("Data")
plt.title("Histogram");
# Out:
# scott
# scott
